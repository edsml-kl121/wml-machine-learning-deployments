# %% [markdown]
# # Deploying a thai-embedder model (Snowflake/snowflake-arctic-embed-l-v2.0)

# %% [markdown]
# <a id="setup"></a>
# ## 1. Set up the environment
#
# Before you use the sample code in this notebook, you must perform the following setup tasks:
#
# -  Contact your Cloud Pack for Data administrator and ask them for your account credentials

# %%
# !pip install sentence-transformers==3.0.0
# !pip install -U ibm-watson-machine-learning
# Out:
# Collecting sentence-transformers==3.0.0
#   Downloading sentence_transformers-3.0.0-py3-none-any.whl.metadata (10 kB)
# Collecting transformers<5.0.0,>=4.34.0 (from sentence-transformers==3.0.0)
#   Downloading transformers-4.48.0-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from sentence-transformers==3.0.0) (4.66.4)
# Requirement already satisfied: torch>=1.11.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from sentence-transformers==3.0.0) (2.1.2)
# Requirement already satisfied: numpy in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from sentence-transformers==3.0.0) (1.26.4)
# Requirement already satisfied: scikit-learn in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from sentence-transformers==3.0.0) (1.3.0)
# Requirement already satisfied: scipy in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from sentence-transformers==3.0.0) (1.11.4)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from sentence-transformers==3.0.0) (0.20.3)
# Requirement already satisfied: Pillow in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from sentence-transformers==3.0.0) (10.3.0)
# Requirement already satisfied: filelock in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers==3.0.0) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers==3.0.0) (2023.10.0)
# Requirement already satisfied: requests in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers==3.0.0) (2.32.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers==3.0.0) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers==3.0.0) (4.11.0)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers==3.0.0) (23.2)
# Requirement already satisfied: sympy in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers==3.0.0) (1.12)
# Requirement already satisfied: networkx in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers==3.0.0) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers==3.0.0) (3.1.4)
# Collecting huggingface-hub>=0.15.1 (from sentence-transformers==3.0.0)
#   Downloading huggingface_hub-0.27.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers==3.0.0) (2023.10.3)
# Collecting tokenizers<0.22,>=0.21 (from transformers<5.0.0,>=4.34.0->sentence-transformers==3.0.0)
#   Downloading tokenizers-0.21.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting safetensors>=0.4.1 (from transformers<5.0.0,>=4.34.0->sentence-transformers==3.0.0)
#   Downloading safetensors-0.5.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from scikit-learn->sentence-transformers==3.0.0) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from scikit-learn->sentence-transformers==3.0.0) (2.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from jinja2->torch>=1.11.0->sentence-transformers==3.0.0) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers==3.0.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers==3.0.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers==3.0.0) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers==3.0.0) (2024.12.14)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from sympy->torch>=1.11.0->sentence-transformers==3.0.0) (1.3.0)
# Downloading sentence_transformers-3.0.0-py3-none-any.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.7/224.7 kB 29.3 MB/s eta 0:00:00
# Downloading transformers-4.48.0-py3-none-any.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 75.9 MB/s eta 0:00:00:00:0100:01
# Downloading huggingface_hub-0.27.1-py3-none-any.whl (450 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 450.7/450.7 kB 54.7 MB/s eta 0:00:00
# Downloading safetensors-0.5.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (461 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.0/462.0 kB 53.6 MB/s eta 0:00:00
# Downloading tokenizers-0.21.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 40.7 MB/s eta 0:00:0000:0100:01
# Installing collected packages: safetensors, huggingface-hub, tokenizers, transformers, sentence-transformers
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.20.3
#     Uninstalling huggingface-hub-0.20.3:
#       Successfully uninstalled huggingface-hub-0.20.3
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.15.2
#     Uninstalling tokenizers-0.15.2:
#       Successfully uninstalled tokenizers-0.15.2
# Successfully installed huggingface-hub-0.27.1 safetensors-0.5.2 sentence-transformers-3.0.0 tokenizers-0.21.0 transformers-4.48.0
# Requirement already satisfied: ibm-watson-machine-learning in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (1.0.367)
# Requirement already satisfied: requests in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-watson-machine-learning) (2.32.2)
# Requirement already satisfied: urllib3 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-watson-machine-learning) (1.26.19)
# Requirement already satisfied: pandas<2.2.0,>=0.24.2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-watson-machine-learning) (2.1.4)
# Requirement already satisfied: certifi in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-watson-machine-learning) (2024.12.14)
# Requirement already satisfied: lomond in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-watson-machine-learning) (0.3.3)
# Requirement already satisfied: tabulate in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-watson-machine-learning) (0.8.10)
# Requirement already satisfied: packaging in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-watson-machine-learning) (23.2)
# Requirement already satisfied: ibm-cos-sdk<2.14.0,>=2.12.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-watson-machine-learning) (2.13.4)
# Requirement already satisfied: importlib-metadata in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-watson-machine-learning) (7.0.1)
# Requirement already satisfied: ibm-cos-sdk-core==2.13.4 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watson-machine-learning) (2.13.4)
# Requirement already satisfied: ibm-cos-sdk-s3transfer==2.13.4 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watson-machine-learning) (2.13.4)
# Requirement already satisfied: jmespath<=1.0.1,>=0.10.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watson-machine-learning) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-cos-sdk-core==2.13.4->ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watson-machine-learning) (2.8.2)
# Requirement already satisfied: numpy<2,>=1.23.2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from pandas<2.2.0,>=0.24.2->ibm-watson-machine-learning) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from pandas<2.2.0,>=0.24.2->ibm-watson-machine-learning) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from pandas<2.2.0,>=0.24.2->ibm-watson-machine-learning) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from requests->ibm-watson-machine-learning) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from requests->ibm-watson-machine-learning) (3.7)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from importlib-metadata->ibm-watson-machine-learning) (3.20.2)
# Requirement already satisfied: six>=1.10.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from lomond->ibm-watson-machine-learning) (1.16.0)

# %%
import numpy as np
import requests
from ibm_watson_machine_learning import APIClient

# %% [markdown]
# ### Connection to WML
#
# Authenticate the Watson Machine Learning service on IBM Cloud Pack for Data. You need to provide platform `url` and `api_key`.

# %%
# For on premise

# wml_credentials = {
#     "username": username,
#     "apikey": api_key,
#     "url": url,
#     "instance_id": 'openshift',
#     "version": '4.6'
# }

# For Saas
url='https://us-south.ml.cloud.ibm.com'
api_key='APIKEY'
wml_credentials = {
        "url": url,
        "apikey": api_key
    }

client = APIClient(wml_credentials)

# %% [markdown]
# ### Working with spaces
#
# First of all, you need to create a space that will be used for your work. If you do not have space already created, you can use `{PLATFORM_URL}/ml-runtime/spaces?context=icp4data` to create one.
#
# - Click New Deployment Space
# - Create an empty space
# - Go to space `Settings` tab
# - Copy `space_id` and paste it below
#
# **Tip**: You can also use SDK to prepare the space for your work. More information can be found [here](https://github.com/IBM/watson-machine-learning-samples/blob/master/cpd4.5/notebooks/python_sdk/instance-management/Space%20management.ipynb).
#
# **Action**: Assign space ID below

# %%
space_id = 'SPACEID'

# %% [markdown]
# You can use `list` method to print all existing spaces.

# %%
client.spaces.list(limit=10)
# Out:
# ------------------------------------  --------------------------------------  ------------------------
# ID                                    NAME                                    CREATED
# c0c2c707-16bf-4620-929c-b0b5dae3116c  hugging-face-level1                     2024-04-13T08:44:07.135Z
# e01b6ae7-3154-42ba-9fd3-ea298462286c  deploy                                  2024-02-28T09:28:04.456Z
# 4952f856-65b4-4df7-8523-08a012674e68  dep                                     2024-02-09T08:23:16.229Z
# 5fb9392c-787b-43a3-91e3-49c3b0355379  Tuning Space                            2024-02-07T05:27:24.684Z
# f45fc607-d0b7-47fe-bdd7-65933e349238  deploy_gov_test2                        2023-12-27T10:15:15.265Z
# a241367f-54e4-4fc8-b60a-d36ccb9e6bb1  deploy_gov_test                         2023-12-27T10:14:50.217Z
# 1975323a-9edf-4466-a381-6c104e5522f5  deploy_sepi2                            2023-12-27T10:13:42.684Z
# 5905937b-648b-4595-bd0a-0e330f8b099d  watsonx-governance-production           2023-12-27T08:43:23.572Z
# db643a93-e681-45de-b4d0-118f262e4bff  watsonx-governance-incubation-practice  2023-12-27T08:23:47.787Z
# 7716c0a1-d194-453d-b96e-07c332b26df7  watsonx-governance-bootcamp             2023-12-27T07:36:24.395Z
# ------------------------------------  --------------------------------------  ------------------------
#                                      ID  \
# 0  c0c2c707-16bf-4620-929c-b0b5dae3116c
# 1  e01b6ae7-3154-42ba-9fd3-ea298462286c
# 2  4952f856-65b4-4df7-8523-08a012674e68
# 3  5fb9392c-787b-43a3-91e3-49c3b0355379
# 4  f45fc607-d0b7-47fe-bdd7-65933e349238
# 5  a241367f-54e4-4fc8-b60a-d36ccb9e6bb1
# 6  1975323a-9edf-4466-a381-6c104e5522f5
# 7  5905937b-648b-4595-bd0a-0e330f8b099d
# 8  db643a93-e681-45de-b4d0-118f262e4bff
# 9  7716c0a1-d194-453d-b96e-07c332b26df7
#
#                                      NAME                   CREATED
# 0                     hugging-face-level1  2024-04-13T08:44:07.135Z
# 1                                  deploy  2024-02-28T09:28:04.456Z
# 2                                     dep  2024-02-09T08:23:16.229Z
# 3                            Tuning Space  2024-02-07T05:27:24.684Z
# 4                        deploy_gov_test2  2023-12-27T10:15:15.265Z
# 5                         deploy_gov_test  2023-12-27T10:14:50.217Z
# 6                            deploy_sepi2  2023-12-27T10:13:42.684Z
# 7           watsonx-governance-production  2023-12-27T08:43:23.572Z
# 8  watsonx-governance-incubation-practice  2023-12-27T08:23:47.787Z
# 9             watsonx-governance-bootcamp  2023-12-27T07:36:24.395Z

# %% [markdown]
# To be able to interact with all resources available in Watson Machine Learning, you need to set **space** which you will be using.

# %%
client.set.default_space(space_id)
# Out:
# 'SUCCESS'

# %% [markdown]
# ## Model Prep

# %%
# %%writefile environment.yml
# channels:
#   - empty
#   - nodefaults
# dependencies:
# - pip:
#   - sentence-transformers==3.0.0
# Out:
# Writing environment.yml

# %%
def my_embedding_function():
    from sentence_transformers import SentenceTransformer
    # model_name = 'kornwtp/simcse-model-phayathaibert'  # Replace with the desired model name
    # Load the model
    model_name = 'Snowflake/snowflake-arctic-embed-l-v2.0'
    try:
        model = SentenceTransformer(model_name)
    except Exception as e:
        return {"error": str(e)}
    
    def score(payload):
        # we assume only one batch is sent
        sentences = payload['input_data'][0]['values'][0]
        try:
            embeddings = model.encode(sentences)
            return {
                'predictions': [
                    {
                        'fields': ['sentence', 'embedding'],
                        'values': [[sentence, embedding.tolist()] for sentence, embedding in zip(sentences, embeddings)]
                    }
                ]
            }
        except Exception as e:
            return {"error": str(e)}
    return score

# Example usage:
embedding_function = my_embedding_function()

# Example payload
payload = {
    'input_data': [
        {
            'values': [
                ["กลุ่มผู้ชายเล่นฟุตบอลบนชายหาด", "กลุ่มเด็กชายกำลังเล่นฟุตบอลบนชายหาด"]
            ]
        }
    ]
}

result = embedding_function(payload)
print(result)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/203 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/250k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/784 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.27G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.34k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/964 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/297 [00:00<?, ?B/s]
# {'predictions': [{'fields': ['sentence', 'embedding'], 'values': [['กลุ่มผู้ชายเล่นฟุตบอลบนชายหาด', [-0.010231428779661655, 0.03986641392111778, -0.042735446244478226, -0.07801564782857895, -0.02775867097079754, -0.011078746989369392, 0.04653536528348923, 0.006247743498533964, -0.018073633313179016, -0.03230619058012962, 0.0013638574164360762, 0.003952351864427328, -0.006624063476920128, -0.008124599233269691, 0.03322526067495346, -0.012820265255868435, 0.08280769735574722, -0.04554062336683273, 0.07518007606267929, 0.014035808853805065, -0.06600766628980637, -0.017680874094367027, 0.016119062900543213, 0.02654307521879673, -0.019373562186956406, -0.020762771368026733, 0.021892499178647995, -0.01066155917942524, -0.022246651351451874, -0.02212711237370968, -0.0077729313634335995, 0.030249232426285744, 0.0379086434841156, -0.056836262345314026, -0.046900276094675064, 0.04048091918230057, -0.010090958327054977, 0.017412574961781502, -0.1286299228668213, -0.006412295158952475, 0.015991654247045517, 0.043936751782894135, 0.0014549016486853361, -0.044297292828559875, -0.01576402224600315, -0.08088015019893646, 0.012383827939629555, -0.0456196554005146, -0.10069603472948074, 0.022771023213863373, -0.06514221429824829, -0.00259392149746418, 0.019610436633229256, 0.014643974602222443, -0.014926332049071789, -0.007703930605202913, 0.10168052464723587, 0.0013920149067416787, -0.04228725656867027, 0.01771809346973896, 0.0322522297501564, 0.0885956808924675, 0.012044411152601242, -0.021948639303445816, -0.022659705951809883, 0.04895716905593872, 0.06711823493242264, -0.013735837303102016, -0.03462550789117813, -0.0020653826650232077, -0.012734880670905113, -0.06753792613744736, 0.021327704191207886, 0.03194073587656021, -0.04235736280679703, -0.0437011644244194, -0.02132043056190014, -0.03739303722977638, 0.0034767123870551586, 0.043744102120399475, 0.11721881479024887, -0.0081627843901515, 0.007351198233664036, -0.023920981213450432, -0.025795862078666687, 0.012062717229127884, 0.07163994759321213, 0.0013191401958465576, -0.00568721117451787, -0.017168449237942696, 0.0054154894314706326, -0.05528991296887398, 0.12155415862798691, -0.029383966699242592, -0.016179002821445465, 0.010867063887417316, -0.005669448524713516, -0.04407482594251633, -0.05747343599796295, -0.005061506759375334, 0.10224037617444992, 0.051497191190719604, -0.042302876710891724, -0.06590518355369568, -0.03106492944061756, 0.03935877978801727, 0.03544360399246216, 0.05713820457458496, 0.031035136431455612, -0.036561816930770874, 0.017145559191703796, -0.022500408813357353, 0.012187715619802475, 0.05882930010557175, -0.022086048498749733, 0.04560116305947304, 0.02210863307118416, 0.006576689425855875, 0.04957452416419983, -0.03717019408941269, -0.04008612036705017, 0.04343925416469574, -0.014292529784142971, 0.05482504889369011, 0.03617371991276741, 0.031963665038347244, -0.10578867048025131, 0.04646919295191765, -0.039175134152173996, -0.006712897215038538, 0.02452900819480419, 0.011213667690753937, 0.060893431305885315, 0.04813764989376068, 0.03130323812365532, 0.013410423882305622, -0.0477069690823555, -0.013676892966032028, -0.003584589110687375, -0.06437230855226517, 0.006048670969903469, 0.018318774178624153, 0.005257231183350086, 0.04938904196023941, -0.012869124300777912, 0.005982700269669294, -0.021464766934514046, 0.05149119719862938, 0.020832927897572517, 0.04036446288228035, -0.04304180666804314, -0.030501138418912888, 0.00635925168171525, -0.0016361881280317903, -0.021528098732233047, 0.034671153873205185, -0.07092288881540298, -0.05050069838762283, -0.01669643260538578, 0.01262417621910572, 0.062394723296165466, -0.055163297802209854, 0.045970749109983444, -0.005230175796896219, 0.011063694022595882, -0.010213984176516533, 0.07092401385307312, -0.08740516752004623, -0.03584377095103264, -0.002703192876651883, -0.047563351690769196, 0.019696705043315887, -0.018368180841207504, 0.07291025668382645, -0.08832082152366638, 0.07268304377794266, -0.0665111914277 ...

# %%
client.repository.list_functions()
# Out:
# ------------------------------------  -------------------  ------------------------  ------  ----------  ----------------
# GUID                                  NAME                 CREATED                   TYPE    SPEC_STATE  SPEC_REPLACEMENT
# e8c5fc81-321f-4ecd-a4ec-cb2413a9b916  simcse embedder-GPU  2024-12-26T17:36:06.977Z  python
# 660402af-313b-4e5e-b3be-e4f82fd4fb55  simcse embedder-GPU  2024-12-26T17:34:38.340Z  python
# 4c21af19-0e57-4d00-910d-07fb34f95cc0  simcse embedder-v2   2024-12-11T08:51:12.968Z  python
# 2c52a08e-15ca-42a5-865d-a52677254455  simcse embedder-v2   2024-12-11T08:50:10.340Z  python
# f1aeefdf-bce8-417b-bccb-356c6a040bfe  simcse embedder-v2   2024-12-11T08:47:30.165Z  python
# 7becde61-9fca-497d-a363-3656ea52b7b4  simcse embedder-v2   2024-12-11T08:45:56.607Z  python
# ------------------------------------  -------------------  ------------------------  ------  ----------  ----------------
#                                    GUID                 NAME  \
# 0  e8c5fc81-321f-4ecd-a4ec-cb2413a9b916  simcse embedder-GPU
# 1  660402af-313b-4e5e-b3be-e4f82fd4fb55  simcse embedder-GPU
# 2  4c21af19-0e57-4d00-910d-07fb34f95cc0   simcse embedder-v2
# 3  2c52a08e-15ca-42a5-865d-a52677254455   simcse embedder-v2
# 4  f1aeefdf-bce8-417b-bccb-356c6a040bfe   simcse embedder-v2
# 5  7becde61-9fca-497d-a363-3656ea52b7b4   simcse embedder-v2
#
#                     CREATED    TYPE SPEC_STATE SPEC_REPLACEMENT
# 0  2024-12-26T17:36:06.977Z  python
# 1  2024-12-26T17:34:38.340Z  python
# 2  2024-12-11T08:51:12.968Z  python
# 3  2024-12-11T08:50:10.340Z  python
# 4  2024-12-11T08:47:30.165Z  python
# 5  2024-12-11T08:45:56.607Z  python

# %%
client.software_specifications.list()
# Out:
# ----------------------------  ------------------------------------  ----  ------------  --------------------------
# NAME                          ID                                    TYPE  STATE         REPLACEMENT
# default_py3.6                 0062b8c9-8b7d-44a0-a9b9-46c416adcbd9  base  retired       runtime-24.1-py3.11
# autoai-ts_rt23.1-py3.10       01ce9391-1a79-5a33-94fb-2e134337f314  base  constricted   autoai-ts_rt24.1-py3.11
# kernel-spark3.2-scala2.12     020d69ce-7ac1-5e68-ac1a-31189867356a  base  retired
# pytorch-onnx_1.3-py3.7-edt    069ea134-3346-5748-b513-49120e15d288  base  retired
# tensorflow_rt23.1-py3.10      079a91e0-245f-5269-8926-3c20b28f37dc  base  constricted   tensorflow_rt24.1-py3.11
# scikit-learn_0.20-py3.6       09c5a1d0-9c1e-4473-a344-eb7b665ff687  base  retired       runtime-24.1-py3.11
# spark-mllib_3.0-scala_2.12    09f4cff0-90a7-5899-b9ed-1ef348aebdee  base  retired
# pytorch-onnx_rt22.1-py3.9     0b848dd4-e681-5599-be41-b5f6fccc6471  base  retired       pytorch-onnx_rt24.1-py3.11
# ai-function_0.1-py3.6         0cdb0f1e-5376-4f4d-92dd-da3b69aa9bda  base  retired       runtime-24.1-py3.11
# watsonx-cfm-caikit-1.0        0cee3c55-472f-57b1-84bd-72f5d066dbe4  base  not_provided
# shiny-r3.6                    0e6e79df-875e-4f24-8ae9-62dcc2148306  base  retired
# tensorflow_2.4-py3.7-horovod  1092590a-307d-563d-9b62-4eb7d64b3f22  base  retired       tensorflow_rt24.1-py3.11
# pytorch_1.1-py3.6             10ac12d6-6b30-4ccd-8392-3e922c096a92  base  retired       runtime-24.1-py3.11
# tensorflow_1.15-py3.6-ddl     111e41b3-de2d-5422-a4d6-bf776828c4b7  base  retired
# autoai-kb_rt22.2-py3.10       125b6d9a-5b1f-5e8d-972a-b251688ccf40  base  retired       autoai-kb_rt24.1-py3.11
# watsonx-textgen-fm-1.0        129aec82-7e65-5c78-b812-4c0a74b916f5  base  not_provided
# runtime-22.1-py3.9            12b83a17-24d8-5082-900f-0ab31fbfd3cb  base  retired       runtime-24.1-py3.11
# masking-flows-spark           13666829-5570-53a7-927b-52d42a101d93  base  not_provided
# kernel-spark3.3-py3.10        147e6777-ccd1-5886-8571-5356abc20839  base  retired
# scikit-learn_0.22-py3.6       154010fa-5b3b-4ac1-82af-4d5ee5abbc85  base  retired       runtime-24.1-py3.11
# pytorch-onnx_rt23.1-py3.10    195067e6-4c5e-5fab-8bd0-e7623a88b4d3  base  constricted   pytorch-onnx_rt24.1-py3.11
# default_r3.6                  1b70aec3-ab34-4b87-8aa0-a4a3c8296a36  base  retired
# pytorch-onnx_1.3-py3.6        1bc6029a-cc97-56da-b8e0-39c3880dbbe7  base  retired       runtime-24.1-py3.11
# kernel-spark3.3-r3.6          1c9e5454-f216-59dd-a20e-474a5cdf5988  base  retired
# tensorflow_2.1-py3.6          1eb25b84-d6ed-5dde-b6a5-3fbdf1665666  base  retired       runtime-24.1-py3.11
# spark-mllib_3.2               20047f72-0a98-58c7-9ff5-a77b012eb8f5  base  retired       spark-mllib_3.3
# tensorflow_2.4-py3.8-horovod  217c16f6-178f-56bf-824a-b19f20564c49  base  retired       tensorflow_rt24.1-py3.11
# runtime-22.1-py3.9-cuda       26215f05-08c3-5a41-a1b0-da66306ce658  base  retired       runtime-24.1-py3.11-cuda
# do_py3.8                      295addb5-9ef9-547e-9bf4-92ae3563e720  base  retired
# autoai-ts_3.8-py3.8           2aa0c932-798f-5ae9-abd6-15e0c2402fb5  base  retired       autoai-ts_rt24.1-py3.11
# tensorflow_1.15-py3.6         2b73a275-7cbf-420b-a912-eae7f436e0bc  base  retired       runtime-24.1-py3.11
# kernel-spark3.3-py3.9         2b7961e2-e3b1-5a8c-a491-482c8368839a  base  retired
# tensorflow_rt24.1-py3.11      2c33167d-b11c-5490-a305-3e5e95db5c4d  base  supported
# pytorch_1.2-py3.6             2c8ef57d-2687-4b7d-acce-01f94976dac1  base  retired       runtime-24.1-py3.11
# pytorch-onnx_rt24.1-py3.11    2da185aa-eac3-59a5-bb8e-0e5b60458a15  base  supported
# spark-mllib_2.3               2e51f700-bca0-4b0d-88dc-5c6791338875  base  retired       spark-mllib_3.3
# pytorch-onnx_1.1-py3.6-edt    32983cea-3f32-4400-8965-dde874a8d67e  base  retired       runtime-24.1-py3.11
# runtime-23.1-py3.10           336b29df-e0e1-5e7d-b6a5-f6ab722625b2  base  constricted   runtime-24.1-py3.11
# spark-mllib_3.0-py37          36507ebe-8770-55ba-ab2a-eafe787600e9  base  retired       spark-mllib_3.3
# onnxruntime_opset_19          368d2795-aaa7-59a0-834c-248c64a5a99e  base  supported
# runtime-24.1-py3.11-xc        36e20eca-b269-5e53-8f76-559f5cf898f2  base  not_provided
# spark-mllib_2.4               390d21f8-e58b-4fac-9c55-d7ceda621326  base  retired       spark-mllib_3.3
# autoai-ts_rt22.2-py3.10       396b2e83-0953-5b86-9a55-7ce1628a406f  base  retired       autoai-ts_rt24.1-py3.11
# xgboost_0.82-py3.6            39e31acd-5f30-41dc-ae44-60233c80306e  base  retired       runtime-24.1-py3.11
# pytorch-onnx_1.2-py3.6-edt    40589d0e-7019-4e28-8daa-fb03b6f4fe12  base  retired       runtime-24.1-py3.11
# pytorch-onnx_rt22.2-py3.10    40e73f55-783a-5535-b3fa-0c8b94291431  base  retired       pytorch-onnx_rt24.1-py3.11
# default_r36py38               41c247d3-45f8-5a71-b065-8580229facf0  base  retired
# autoai-ts_rt22.1-py3.9        4269d26e-07ba-5d40-8f66-2d495b0c71f7  base  retired       autoai-ts_rt24.1-py3.11
# autoai-obm_3.0                42b92e18-d9ab-567f-988a-4240ba1ed5f7  base  retired       autoai-obm_3.2
# runtime-24.1-py3.11           45f12dfe-aa78-5b8d-9f38-0ee223c47309  base  supported
# ----------------------------  ------------------------------------  ----  ------------  --------------------------
# Note: Only first 50 records were displayed. To display more use 'limit' parameter.
#                             NAME                                    ID  TYPE  \
# 0                  default_py3.6  0062b8c9-8b7d-44a0-a9b9-46c416adcbd9  base
# 1        autoai-ts_rt23.1-py3.10  01ce9391-1a79-5a33-94fb-2e134337f314  base
# 2      kernel-spark3.2-scala2.12  020d69ce-7ac1-5e68-ac1a-31189867356a  base
# 3     pytorch-onnx_1.3-py3.7-edt  069ea134-3346-5748-b513-49120e15d288  base
# 4       tensorflow_rt23.1-py3.10  079a91e0-245f-5269-8926-3c20b28f37dc  base
# 5        scikit-learn_0.20-py3.6  09c5a1d0-9c1e-4473-a344-eb7b665ff687  base
# 6     spark-mllib_3.0-scala_2.12  09f4cff0-90a7-5899-b9ed-1ef348aebdee  base
# 7      pytorch-onnx_rt22.1-py3.9  0b848dd4-e681-5599-be41-b5f6fccc6471  base
# 8          ai-function_0.1-py3.6  0cdb0f1e-5376-4f4d-92dd-da3b69aa9bda  base
# 9         watsonx-cfm-caikit-1.0  0cee3c55-472f-57b1-84bd-72f5d066dbe4  base
# 10                    shiny-r3.6  0e6e79df-875e-4f24-8ae9-62dcc2148306  base
# 11  tensorflow_2.4-py3.7-horovod  1092590a-307d-563d-9b62-4eb7d64b3f22  base
# 12             pytorch_1.1-py3.6  10ac12d6-6b30-4ccd-8392-3e922c096a92  base
# 13     tensorflow_1.15-py3.6-ddl  111e41b3-de2d-5422-a4d6-bf776828c4b7  base
# 14       autoai-kb_rt22.2-py3.10  125b6d9a-5b1f-5e8d-972a-b251688ccf40  base
# 15        watsonx-textgen-fm-1.0  129aec82-7e65-5c78-b812-4c0a74b916f5  base
# 16            runtime-22.1-py3.9  12b83a17-24d8-5082-900f-0ab31fbfd3cb  base
# 17           masking-flows-spark  13666829-5570-53a7-927b-52d42a101d93  base
# 18        kernel-spark3.3-py3.10  147e6777-ccd1-5886-8571-5356abc20839  base
# 19       scikit-learn_0.22-py3.6  154010fa-5b3b-4ac1-82af-4d5ee5abbc85  base
# 20    pytorch-onnx_rt23.1-py3.10  195067e6-4c5e-5fab-8bd0-e7623a88b4d3  base
# 21                  default_r3.6  1b70aec3-ab34-4b87-8aa0-a4a3c8296a36  base
# 22        pytorch-onnx_1.3-py3.6  1bc6029a-cc97-56da-b8e0-39c3880dbbe7  base
# 23          kernel-spark3.3-r3.6  1c9e5454-f216-59dd-a20e-474a5cdf5988  base
# 24          tensorflow_2.1-py3.6  1eb25b84-d6ed-5dde-b6a5-3fbdf1665666  base
# 25               spark-mllib_3.2  20047f72-0a98-58c7-9ff5-a77b012eb8f5  base
# 26  tensorflow_2.4-py3.8-horovod  217c16f6-178f-56bf-824a-b19f20564c49  base
# 27       runtime-22.1-py3.9-cuda  26215f05-08c3-5a41-a1b0-da66306ce658  base
# 28                      do_py3.8  295addb5-9ef9-547e-9bf4-92ae3563e720  base
# 29           autoai-ts_3.8-py3.8  2aa0c932-798f-5ae9-abd6-15e0c2402fb5  base
# 30         tensorflow_1.15-py3.6  2b73a275-7cbf-420b-a912-eae7f436e0bc  base
# 31         kernel-spark3.3-py3.9  2b7961e2-e3b1-5a8c-a491-482c8368839a  base
# 32      tensorflow_rt24.1-py3.11  2c33167d-b11c-5490-a305-3e5e95db5c4d  base
# 33             pytorch_1.2-py3.6  2c8ef57d-2687-4b7d-acce-01f94976dac1  base
# 34    pytorch-onnx_rt24.1-py3.11  2da185aa-eac3-59a5-bb8e-0e5b60458a15  base
# 35               spark-mllib_2.3  2e51f700-bca0-4b0d-88dc-5c6791338875  base
# 36    pytorch-onnx_1.1-py3.6-edt  32983cea-3f32-4400-8965-dde874a8d67e  base
# 37           runtime-23.1-py3.10  336b29df-e0e1-5e7d-b6a5-f6ab722625b2  base
# 38          spark-mllib_3.0-py37  36507ebe-8770-55ba-ab2a-eafe787600e9  base
# 39          onnxruntime_opset_19  368d2795-aaa7-59a0-834c-248c64a5a99e  base
# 40        runtime-24.1-py3.11-xc  36e20eca-b269-5e53-8f76-559f5cf898f2  base
# 41               spark-mllib_2.4  390d21f8-e58b-4fac-9c55-d7ceda621326  base
# 42       autoai-ts_rt22.2-py3.10  396b2e83-0953-5b86-9a55-7ce1628a406f  base
# 43            xgboost_0.82-py3.6  39e31acd-5f30-41dc-ae44-60233c80306e  base
# 44    pytorch-onnx_1.2-py3.6-edt  40589d0e-7019-4e28-8daa-fb03b6f4fe12  base
# 45    pytorch-onnx_rt22.2-py3.10  40e73f55-783a-5535-b3fa-0c8b94291431  base
# 46               default_r36py38  41c247d3-45f8-5a71-b065-8580229facf0  base
# 47        autoai-ts_rt22.1-py3.9  4269d26e-07ba-5d40-8f66-2d495b0c71f7  base
# 48                autoai-obm_3.0  42b92e18-d9ab-567f-988a-4240ba1ed5f7  base
# 49           runtime-24.1-py3.11  45f12dfe-aa78-5b8d-9f38-0ee223c47309  base
#
#            STATE                 REPLACEMENT
# 0        retired         runtime-24.1-py3.11
# 1    constricted     autoai-ts_rt24.1-py3.11
# 2        retired
# 3        retired
# 4    constricted    tensorflow_rt24.1-py3.11
# 5        retired         runtime-24.1-py3.11
# 6        retired
# 7        retired  pytorch-onnx_rt24.1-py3.11
# 8        retired         runtime-24.1-py3.11
# 9   not_provided
# 10       retired
# 11       retired    tensorflow_rt24.1-py3.11
# 12       retired         runtime-24.1-py3.11
# 13       retired
# 14       retired     autoai-kb_rt24.1-py3.11
# 15  not_provided
# 16       retired         runtime-24.1-py3.11
# 17  not_provided
# 18       retired
# 19       retired         runtime-24.1-py3.11
# 20   constricted  pytorch-onnx_rt24.1-py3.11
# 21       retired
# 22       retired         runtime-24.1-py3.11
# 23       retired
# 24       retired         runtime-24.1-py3.11
# 25       retired             spark-mllib_3.3
# 26       retired    tensorflow_rt24.1-py3.11
# 27       retired    runtime-24.1-py3.11-cuda
# 28       retired
# 29       retired     autoai-ts_rt24.1-py3.11
# 30       retired         runtime-24.1-py3.11
# 31       retired
# 32     supported
# 33       retired         runtime-24.1-py3.11
# 34     supported
# 35       retired             spark-mllib_3.3
# 36       retired         runtime-24.1-py3.11
# 37   constricted         runtime-24.1-py3.11
# 38       retired             spark-mllib_3.3
# 39     supported
# 40  not_provided
# 41       retired             spark-mllib_3.3
# 42       retired     autoai-ts_rt24.1-py3.11
# 43       retired         runtime-24.1-py3.11
# 44       retired         runtime-24.1-py3.11
# 45       retired  pytorch-onnx_rt24.1-py3.11
# 46       retired
# 47       retired     autoai-ts_rt24.1-py3.11
# 48       retired              autoai-obm_3.2
# 49     supported

# %%
client.hardware_specifications.list()
# Out:
# ----------------------  ------------------------------------  --------------------------------------------------------------------------------------------------------------------------------------
# NAME                    ID                                    DESCRIPTION
# WXaaS-XL                0f174b00-46c7-5283-9db8-30bf2d429b49  watsonx.ai extra large
# ML                      5a1f0e64-e420-55ce-bd7a-f6d00bb942cf  A hardware specification providing 4 CPU cores and 32 GiB of memory.
# WXaaS-L                 5f56db8f-0e15-5a59-bd3b-1a72e28855ec  watsonx.ai large
# WXaaS-S                 98da02d8-a815-5384-b4c0-2062515e2a16  watsonx.ai small
# V100x2                  a02f3ab5-6964-4f06-a870-c7cc69187895  2 V100 GPU
# L                       a6c4923b-b8e4-444c-9f43-8a7ec3020110  A hardware specification providing 8 CPU cores and 32 GiB of memory.
# Default Spark           ac59d20a-9c7c-4504-a853-788ef35969da  A hardware specification for Spark with 1 CPU and 4 GiB of memory for master and worker nodes, with 2 workers.
# XXS                     b128f957-581d-46d0-95b6-8af5cd5be580  A hardware specification providing one CPU core and 2 GiB of memory.
# M-Spark                 b2232f7a-bfad-4822-9bce-6ba1af49217a  A hardware specification for Spark service with 2 CPU and 8 GiB of memory for master and 2 CPU and 8 GiB of memory for worker nodes.
# M                       c076e82c-b2a7-4d20-9c0f-1f0c2fdf5a24  A hardware specification providing 4 CPU cores and 16 GiB of memory.
# XL-Spark                c1791762-1333-4dd3-b7bb-228ae287da31  A hardware specification for Spark service with 3 CPU and 12 GiB of memory for master and 4 CPU and 12 GiB of memory for worker nodes.
# K80                     cf70f086-916d-4684-91a7-264c49c6d425  A hardware specification providing 4 CPU cores and 24 GiB of memory with 1 Nvidia K80 GPU.
# XL                      d0aa1ae8-a889-42e2-a099-041b604b9289  A hardware specification providing 16 CPU cores and 64 GiB of memory.
# K80x2                   d0f52aa1-4312-40f6-ad84-f16cf5c6da9e  A hardware specification providing 8 CPU cores and 48 GiB of memory with 2 Nvidia K80 GPUs.
# Notebook Default Spark  d4e4937c-a7a5-5357-ad12-45ee7b1ff380  For notebooks with Spark kernels. The default resource sizes are subject to change.
# S-Spark                 d92943ba-9f47-407d-9280-c85281687a1e  A hardware specification for Spark service with 1 CPU and 4 GiB of memory for master and 2 CPU and 4 GiB of memory for worker nodes.
# XS-Spark                e18b1866-e8fa-49c8-9aa5-dfaaed6ffa43  A hardware specification for Spark with 1 CPU and 4 GiB of memory for master and worker nodes.
# S                       e7ed1d6c-2e89-42d7-aed5-863b972c1d2b  A hardware specification providing 2 CPU cores and 8 GiB of memory.
# K80x4                   ec104857-0389-4649-af8e-971fc11982d0  A hardware specification providing 16 CPU cores and 96 GiB of memory with 4 Nvidia K80 GPUs.
# WXaaS-M                 ef49e794-5476-5735-a03f-88509122b90d  watsonx.ai medium
# L-Spark                 f132f14a-6c0f-4570-b87c-98ad1e297953  A hardware specification for Spark service with 2 CPU and 8 GiB of memory for master and 4 CPU and 9 GiB of memory for worker nodes.
# V100                    f327bdf7-5634-43d8-b1e3-445afeaf18b9  1 V100 GPU
# XS                      f3ebac7d-0a75-410c-8b48-a931428cc4c5  A hardware specification providing one CPU core and 4 GiB of memory.
# ----------------------  ------------------------------------  --------------------------------------------------------------------------------------------------------------------------------------
#                       NAME                                    ID  \
# 0                 WXaaS-XL  0f174b00-46c7-5283-9db8-30bf2d429b49
# 1                       ML  5a1f0e64-e420-55ce-bd7a-f6d00bb942cf
# 2                  WXaaS-L  5f56db8f-0e15-5a59-bd3b-1a72e28855ec
# 3                  WXaaS-S  98da02d8-a815-5384-b4c0-2062515e2a16
# 4                   V100x2  a02f3ab5-6964-4f06-a870-c7cc69187895
# 5                        L  a6c4923b-b8e4-444c-9f43-8a7ec3020110
# 6            Default Spark  ac59d20a-9c7c-4504-a853-788ef35969da
# 7                      XXS  b128f957-581d-46d0-95b6-8af5cd5be580
# 8                  M-Spark  b2232f7a-bfad-4822-9bce-6ba1af49217a
# 9                        M  c076e82c-b2a7-4d20-9c0f-1f0c2fdf5a24
# 10                XL-Spark  c1791762-1333-4dd3-b7bb-228ae287da31
# 11                     K80  cf70f086-916d-4684-91a7-264c49c6d425
# 12                      XL  d0aa1ae8-a889-42e2-a099-041b604b9289
# 13                   K80x2  d0f52aa1-4312-40f6-ad84-f16cf5c6da9e
# 14  Notebook Default Spark  d4e4937c-a7a5-5357-ad12-45ee7b1ff380
# 15                 S-Spark  d92943ba-9f47-407d-9280-c85281687a1e
# 16                XS-Spark  e18b1866-e8fa-49c8-9aa5-dfaaed6ffa43
# 17                       S  e7ed1d6c-2e89-42d7-aed5-863b972c1d2b
# 18                   K80x4  ec104857-0389-4649-af8e-971fc11982d0
# 19                 WXaaS-M  ef49e794-5476-5735-a03f-88509122b90d
# 20                 L-Spark  f132f14a-6c0f-4570-b87c-98ad1e297953
# 21                    V100  f327bdf7-5634-43d8-b1e3-445afeaf18b9
# 22                      XS  f3ebac7d-0a75-410c-8b48-a931428cc4c5
#
#                                           DESCRIPTION
# 0                              watsonx.ai extra large
# 1   A hardware specification providing 4 CPU cores...
# 2                                    watsonx.ai large
# 3                                    watsonx.ai small
# 4                                          2 V100 GPU
# 5   A hardware specification providing 8 CPU cores...
# 6   A hardware specification for Spark with 1 CPU ...
# 7   A hardware specification providing one CPU cor...
# 8   A hardware specification for Spark service wit...
# 9   A hardware specification providing 4 CPU cores...
# 10  A hardware specification for Spark service wit...
# 11  A hardware specification providing 4 CPU cores...
# 12  A hardware specification providing 16 CPU core...
# 13  A hardware specification providing 8 CPU cores...
# 14  For notebooks with Spark kernels. The default ...
# 15  A hardware specification for Spark service wit...
# 16  A hardware specification for Spark with 1 CPU ...
# 17  A hardware specification providing 2 CPU cores...
# 18  A hardware specification providing 16 CPU core...
# 19                                  watsonx.ai medium
# 20  A hardware specification for Spark service wit...
# 21                                         1 V100 GPU
# 22  A hardware specification providing one CPU cor...

# %%
meta_props = {
   client.package_extensions.ConfigurationMetaNames.NAME: "transformers",
   client.package_extensions.ConfigurationMetaNames.TYPE: "conda_yml"
}
pkg_extn_details = client.package_extensions.store(meta_props, "./environment.yml")
pkg_extn_id = client.package_extensions.get_id(pkg_extn_details)


base_id = client.software_specifications.get_id_by_name("runtime-24.1-py3.11")
meta_props = {
   client.software_specifications.ConfigurationMetaNames.NAME: "default with sentence-transformer arctic",
   client.software_specifications.ConfigurationMetaNames.PACKAGE_EXTENSIONS: [{'guid': pkg_extn_id}],
   client.software_specifications.ConfigurationMetaNames.BASE_SOFTWARE_SPECIFICATION: {'guid': base_id}
}
sw_spec_details = client.software_specifications.store(meta_props)
sw_spec_id = client.software_specifications.get_id(sw_spec_details)


# model_details = client.repository.store_model(
#     model=sample_saved_model_filename,
#     meta_props=metadata
# )
# Out:
# Creating package extensions
# SUCCESS

# %%
function_props = {
    client.repository.FunctionMetaNames.NAME: 'snowflake-arctic-embed-l-v2.0',
    client.repository.FunctionMetaNames.SOFTWARE_SPEC_UID: sw_spec_id
}
function_details = client.repository.store_function(my_embedding_function, function_props)
function_id = client.repository.get_function_id(function_details)
print(function_id)
# Out:
# 4e4962a0-e6e4-42d2-96a8-85d57d44a762

# %%
hardware_spec_id = client.hardware_specifications.get_id_by_name('M')


deployment_props = {
    client.deployments.ConfigurationMetaNames.NAME: 'snowflake-arctic-embed-l-v2.0',
    client.deployments.ConfigurationMetaNames.ONLINE: {},
    client.deployments.ConfigurationMetaNames.HARDWARE_SPEC: { "id": hardware_spec_id, 'num_nodes': 1}
}
deployment_details = client.deployments.create(function_id, deployment_props)
deployment_id = client.deployments.get_id(deployment_details)
# Out:
# #######################################################################################
#
# Synchronous deployment creation for uid: '4e4962a0-e6e4-42d2-96a8-85d57d44a762' started
#
# #######################################################################################
#
#
# initializing
# Note: online_url and serving_urls are deprecated and will be removed in a future release. Use inference instead.
# ............

# %%
payload = {
    'input_data': [
        {
            'values': [
                ["กลุ่มผู้ชายเล่นฟุตบอลบนชายหาด", "กลุ่มเด็กชายกำลังเล่นฟุตบอลบนชายหาด"]
            ]
        }
    ]
}

client.deployments.score(deployment_id, payload)
